# %% [markdown]
# # Stable Diffusion WebUI

# %% [markdown]
# 阿里云 DSW 一键脚本v4 By [bilibili@秋葉aaaki](https://space.bilibili.com/12566101)
#
# #### 更新日志
#
# 2023-6-11
#
# - 修复了无法下载模型、无法启动的问题
#
# 2023-5-2
#
# - 添加了插件，修改了插件安装方式
# - 升级 torch 版本
# - 更新了汉化
# - 添加了部分插件（LoRA）
# - 添加了下载文件用的代码
#
# 2023-5-3
#
# - 疑似 torch2 会导致黑图，已取消

# %% [markdown]
# ## 安装 第一次需要执行

# %%
# !apt update
# !apt install -y aria2
# !git clone https://gitcode.net/overbill1683/stable-diffusion-webui
# %cd stable-diffusion-webui
# !mkdir repositories
# %cd repositories
# !git clone "https://gitcode.net/overbill1683/stablediffusion" "stable-diffusion-stability-ai"
# !git clone "https://gitcode.net/overbill1683/taming-transformers" "taming-transformers"
# !git clone "https://gitcode.net/overbill1683/k-diffusion" "k-diffusion"
# !git clone "https://gitcode.net/overbill1683/CodeFormer" "CodeFormer"
# !git clone "https://gitcode.net/overbill1683/BLIP" "BLIP"

# %cd /mnt/workspace/stable-diffusion-webui
# !wget -O "config.json" "https://gitcode.net/Akegarasu/sd-webui-configs/-/raw/master/config.json"
# Out:
# Get:1 http://mirrors.cloud.aliyuncs.com/ubuntu jammy InRelease [270 kB]
# Get:2 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-updates InRelease [119 kB]
# Get:3 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-backports InRelease [109 kB]
# Get:4 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-security InRelease [110 kB]
# Get:5 http://mirrors.cloud.aliyuncs.com/ubuntu jammy/universe Sources [22.0 MB]
# Get:6 http://mirrors.cloud.aliyuncs.com/ubuntu jammy/main Sources [1668 kB]
# Get:7 http://mirrors.cloud.aliyuncs.com/ubuntu jammy/multiverse Sources [361 kB]
# Get:8 http://mirrors.cloud.aliyuncs.com/ubuntu jammy/restricted Sources [28.2 kB]
# Get:9 http://mirrors.cloud.aliyuncs.com/ubuntu jammy/main amd64 Packages [1792 kB]
# Get:10 http://mirrors.cloud.aliyuncs.com/ubuntu jammy/universe amd64 Packages [17.5 MB]
# Get:11 http://mirrors.cloud.aliyuncs.com/ubuntu jammy/multiverse amd64 Packages [266 kB]
# Get:12 http://mirrors.cloud.aliyuncs.com/ubuntu jammy/restricted amd64 Packages [164 kB]
# Get:13 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-updates/universe Sources [359 kB]
# Get:14 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-updates/main Sources [558 kB]
# Get:15 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-updates/restricted Sources [59.7 kB]
# Get:16 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-updates/multiverse Sources [21.0 kB]
# Get:17 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-updates/universe amd64 Packages [1278 kB]
# Get:18 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-updates/multiverse amd64 Packages [49.8 kB]
# Get:19 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-updates/restricted amd64 Packages [1415 kB]
# Get:20 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-updates/main amd64 Packages [1455 kB]
# Get:21 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-backports/universe Sources [10.6 kB]
# Get:22 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-backports/main Sources [9389 B]
# Get:23 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-backports/universe amd64 Packages [32.6 kB]
# Get:24 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-backports/main amd64 Packages [78.3 kB]
# Get:25 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-security/main Sources [286 kB]
# Get:26 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-security/restricted Sources [56.8 kB]
# Get:27 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-security/multiverse Sources [11.3 kB]
# Get:28 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-security/universe Sources [208 kB]
# Get:29 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-security/main amd64 Packages [1185 kB]
# Get:30 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-security/multiverse amd64 Packages [44.0 kB]
# Get:31 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-security/universe amd64 Packages [1012 kB]
# Get:32 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-security/restricted amd64 Packages [1389 kB]
# Fetched 53.8 MB in 3s (16.9 MB/s)33m
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 105 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libaria2-0 libc-ares2 libssh2-1
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2 libssh2-1
# 0 upgraded, 4 newly installed, 0 to remove and 105 not upgraded.
# Need to get 1622 kB of archives.
# After this operation, 5817 kB of additional disk space will be used.
# Get:1 http://mirrors.cloud.aliyuncs.com/ubuntu jammy-updates/main amd64 libc-ares2 amd64 1.18.1-1ubuntu0.22.04.2 [45.0 kB]
# Get:2 http://mirrors.cloud.aliyuncs.com/ubuntu jammy/universe amd64 libssh2-1 amd64 1.10.0-3 [109 kB]
# Get:3 http://mirrors.cloud.aliyuncs.com/ubuntu jammy/universe amd64 libaria2-0 amd64 1.36.0-1 [1086 kB]
# Get:4 http://mirrors.cloud.aliyuncs.com/ubuntu jammy/universe amd64 aria2 amd64 1.36.0-1 [381 kB]
# Fetched 1622 kB in 0s (9460 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 20089 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.2_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 87Progress: [  6%] [###.......................................................] 8Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.2) ...
# 7Progress: [ 12%] [######....................................................] 8Selecting previously unselected package libssh2-1:amd64.
# Preparing to unpack .../libssh2-1_1.10.0-3_amd64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking libssh2-1:amd64 (1.10.0-3) ...
# 7Progress: [ 24%] [#############.............................................] 8Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# 7Progress: [ 29%] [#################.........................................] 8Unpacking libaria2-0:amd64 (1.36.0-1) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# 7Progress: [ 41%] [#######################...................................] 8Unpacking aria2 (1.36.0-1) ...
# 7Progress: [ 47%] [###########################...............................] 8Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.2) ...
# 7Progress: [ 53%] [##############################............................] 87Progress: [ 59%] [##################################........................] 8Setting up libssh2-1:amd64 (1.10.0-3) ...
# 7Progress: [ 65%] [#####################################.....................] 87Progress: [ 71%] [########################################..................] 8Setting up libaria2-0:amd64 (1.36.0-1) ...
# 7Progress: [ 76%] [############################################..............] 87Progress: [ 82%] [###############################################...........] 8Setting up aria2 (1.36.0-1) ...
# 7Progress: [ 88%] [###################################################.......] 87Progress: [ 94%] [######################################################....] 8Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
#
# 78Cloning into 'stable-diffusion-webui'...
# warning: redirecting to https://gitcode.net/overbill1683/stable-diffusion-webui.git/
# remote: Enumerating objects: 359, done.
# remote: Counting objects: 100% (359/359), done.
# remote: Compressing objects: 100% (202/202), done.
# remote: Total 27902 (delta 229), reused 269 (delta 157), pack-reused 27543
# Receiving objects: 100% (27902/27902), 30.48 MiB | 23.21 MiB/s, done.
# Resolving deltas: 100% (20072/20072), done.
# /mnt/workspace/stable-diffusion-webui
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /mnt/workspace/stable-diffusion-webui/repositories
# Cloning into 'stable-diffusion-stability-ai'...
# warning: redirecting to https://gitcode.net/overbill1683/stablediffusion.git/
# remote: Enumerating objects: 574, done.
# remote: Counting objects: 100% (574/574), done.
# remote: Compressing objects: 100% (287/287), done.
# remote: Total 574 (delta 266), reused 574 (delta 266), pack-reused 0
# Receiving objects: 100% (574/574), 73.48 MiB | 13.17 MiB/s, done.
# Resolving deltas: 100% (266/266), done.
# Cloning into 'taming-transformers'...
# warning: redirecting to https://gitcode.net/overbill1683/taming-transformers.git/
# remote: Enumerating objects: 1342, done.
# remote: Counting objects: 100% (1342/1342), done.
# remote: Compressing objects: 100% (1045/1045), done.
# remote: Total 1342 (delta 281), reused 1338 (delta 279), pack-reused 0
# Receiving objects: 100% (1342/1342), 409.77 MiB | 24.50 MiB/s, done.
# Resolving deltas: 100% (281/281), done.
# Cloning into 'k-diffusion'...
# warning: redirecting to https://gitcode.net/overbill1683/k-diffusion.git/
# remote: Enumerating objects: 147, done.
# remote: Counting objects: 100% (147/147), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 1323 (delta 99), reused 77 (delta 57), pack-reused 1176
# Receiving objects: 100% (1323/1323), 257.07 KiB | 2.68 MiB/s, done.
# Resolving deltas: 100% (916/916), done.
# Cloning into 'CodeFormer'...
# warning: redirecting to https://gitcode.net/overbill1683/CodeFormer.git/
# remote: Enumerating objects: 594, done.
# remote: Counting objects: 100% (594/594), done.
# remote: Compressing objects: 100% (357/357), done.
# remote: Total 594 (delta 290), reused 466 (delta 228), pack-reused 0
# Receiving objects: 100% (594/594), 17.30 MiB | 4.32 MiB/s, done.
# Resolving deltas: 100% (290/290), done.
# Cloning into 'BLIP'...
# warning: redirecting to https://gitcode.net/overbill1683/BLIP.git/
# remote: Enumerating objects: 277, done.
# remote: Counting objects: 100% (277/277), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 277 (delta 151), reused 273 (delta 150), pack-reused 0
# Receiving objects: 100% (277/277), 7.16 MiB | 22.42 MiB/s, done.
# Resolving deltas: 100% (151/151), done.
# /mnt/workspace/stable-diffusion-webui
# --2023-11-01 12:55:36--  https://gitcode.net/Akegarasu/sd-webui-configs/-/raw/master/config.json
# Resolving gitcode.net (gitcode.net)... 119.3.229.170
# Connecting to gitcode.net (gitcode.net)|119.3.229.170|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9427 (9.2K) [text/plain]
# Saving to: ‘config.json’
#
# config.json         100%[===================>]   9.21K  --.-KB/s    in 0s
#
# 2023-11-01 12:55:36 (134 MB/s) - ‘config.json’ saved [9427/9427]

# %%
## 安装常用插件，填写github链接，一行一个
extension_urls = """
https://gitcode.net/ranting8323/a1111-sd-webui-tagcomplete
https://gitcode.net/overbill1683/stable-diffusion-webui-localization-zh_Hans
https://gitcode.net/ranting8323/sd-webui-additional-networks
https://gitcode.net/ranting8323/sd-webui-infinite-image-browsing
https://gitcode.net/ranting8323/stable-diffusion-webui-wd14-tagger
"""

extensions = extension_urls.strip().split("\n")

# %cd /mnt/workspace/stable-diffusion-webui
for e in extensions:
    # !git -C "extensions" clone {e}
# Out:
# /mnt/workspace/stable-diffusion-webui
# Cloning into 'a1111-sd-webui-tagcomplete'...
# warning: redirecting to https://gitcode.net/ranting8323/a1111-sd-webui-tagcomplete.git/
# remote: Enumerating objects: 467, done.
# remote: Counting objects: 100% (467/467), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 1968 (delta 345), reused 400 (delta 292), pack-reused 1501
# Receiving objects: 100% (1968/1968), 4.01 MiB | 1.60 MiB/s, done.
# Resolving deltas: 100% (1226/1226), done.
# Cloning into 'stable-diffusion-webui-localization-zh_Hans'...
# warning: redirecting to https://gitcode.net/overbill1683/stable-diffusion-webui-localization-zh_Hans.git/
# remote: Enumerating objects: 218, done.
# remote: Counting objects: 100% (218/218), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 2876 (delta 155), reused 195 (delta 138), pack-reused 2658
# Receiving objects: 100% (2876/2876), 1.73 MiB | 5.30 MiB/s, done.
# Resolving deltas: 100% (1877/1877), done.
# Cloning into 'sd-webui-additional-networks'...
# warning: redirecting to https://gitcode.net/ranting8323/sd-webui-additional-networks.git/
# remote: Enumerating objects: 809, done.
# remote: Counting objects: 100% (809/809), done.
# remote: Compressing objects: 100% (371/371), done.
# remote: Total 809 (delta 457), reused 773 (delta 430), pack-reused 0
# Receiving objects: 100% (809/809), 246.06 KiB | 491.00 KiB/s, done.
# Resolving deltas: 100% (457/457), done.
# Cloning into 'sd-webui-infinite-image-browsing'...
# warning: redirecting to https://gitcode.net/ranting8323/sd-webui-infinite-image-browsing.git/
# remote: Enumerating objects: 1104, done.
# remote: Counting objects: 100% (1104/1104), done.
# remote: Compressing objects: 100% (712/712), done.
# remote: Total 7912 (delta 580), reused 811 (delta 363), pack-reused 6808
# Receiving objects: 100% (7912/7912), 36.30 MiB | 25.30 MiB/s, done.
# Resolving deltas: 100% (4569/4569), done.
# Cloning into 'stable-diffusion-webui-wd14-tagger'...
# warning: redirecting to https://gitcode.net/ranting8323/stable-diffusion-webui-wd14-tagger.git/
# remote: Enumerating objects: 361, done.
# remote: Counting objects: 100% (361/361), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 361 (delta 193), reused 340 (delta 179), pack-reused 0
# Receiving objects: 100% (361/361), 1.08 MiB | 4.16 MiB/s, done.
# Resolving deltas: 100% (193/193), done.

# %% [markdown]
# ## 下载模型

# %%
def aria2(url, filename, d):
    # !aria2c --console-log-level=error -c -x 16 -s 16 {url} -o {filename} -d {d}

model_url = '"https://modelscope.cn/api/v1/models/dienstag/anything-v4.0/repo?Revision=master&FilePath=anything-v4.0-pruned-fp16.safetensors"'
aria2(model_url, "anything-v4.0-pruned-fp16.safetensors", "/mnt/workspace/stable-diffusion-webui/models/Stable-diffusion")
# Out:
# [#9336ca 1.9GiB/1.9GiB(99%) CN:6 DL:273MiB]]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 9336ca|OK  |   273MiB/s|/mnt/workspace/stable-diffusion-webui/models/Stable-diffusion/anything-v4.0-pruned-fp16.safetensors
#
# Status Legend:
# (OK):download completed.

# %% [markdown]
# ## 下载 VAE

# %%
VAE_URL = '"https://modelscope.cn/api/v1/models/dienstag/anything-v4.0/repo?Revision=master&FilePath=anything-v4.0.vae.pt"'
aria2(VAE_URL, "animevae.pt", "/mnt/workspace/stable-diffusion-webui/models/VAE")
# Out:
# [#966122 685MiB/784MiB(87%) CN:11 DL:259MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 966122|OK  |   261MiB/s|/mnt/workspace/stable-diffusion-webui/models/VAE/animevae.pt
#
# Status Legend:
# (OK):download completed.

# %% [markdown]
# ## 下载 其他文件（可选）

# %%
# 这部分是可选的！！！！！有需要再执行！！！！！！！ 修改对应文本，运行即可下载文件
def aria2(url, filename, d):
    # !aria2c --console-log-level=error -c -x 16 -s 16 {url} -o {filename} -d {d}

DOWNLOAD_URL = "文件链接" # 文件链接，需要下载的url直链才可以
FILE_NAME = "aki" # 下载保存的文件名
SAVE_DIR = "/mnt/workspace" # 文件保存的路径
aria2(DOWNLOAD_URL, FILE_NAME, SAVE_DIR)

# %% [markdown]
# ## 启动WebUI

# %%
import os
package_envs  = [
      {
        "env": "GFPGAN_PACKAGE",
        "url": "git+https://gitcode.net/overbill1683/GFPGAN.git@8d2447a2d918f8eba5a4a01463fd48e45126a379"
      },
      {
        "env": "CLIP_PACKAGE",
        "url": "git+https://gitcode.net/overbill1683/CLIP.git@d50d76daa670286dd6cacf3bcd80b5e4823fc8e1"
      },
      {
        "env": "OPENCLIP_PACKAGE",
        "url": "git+https://gitcode.net/overbill1683/open_clip.git@bb6e834e9c70d9c27d0dc3ecedeebeaeb1ffad6b"
      }
]
os.environ["PIP_INDEX_URL"] = "https://mirror.baidu.com/pypi/simple"
for i in package_envs:
    os.environ[i["env"]] = i["url"]

# %cd /mnt/workspace/stable-diffusion-webui
# !python launch.py --no-download-sd-model --xformers --share --listen --enable-insecure-extension-access
# Out:
# /mnt/workspace/stable-diffusion-webui
# Python 3.10.6 (main, Mar 10 2023, 10:55:28) [GCC 11.3.0]
# Version: v1.6.0
# Commit hash: 5ef669de080814067961f28357256e8fe27544f4
# Cloning Stable Diffusion XL into /mnt/workspace/stable-diffusion-webui/repositories/generative-models...
# Cloning into '/mnt/workspace/stable-diffusion-webui/repositories/generative-models'...
# remote: Enumerating objects: 740, done.
# remote: Counting objects: 100% (393/393), done.
# remote: Compressing objects: 100% (157/157), done.
# remote: Total 740 (delta 307), reused 236 (delta 236), pack-reused 347
# Receiving objects: 100% (740/740), 22.31 MiB | 10.53 MiB/s, done.
# Resolving deltas: 100% (378/378), done.
# Fetching updates for K-diffusion...
# Checking out commit for K-diffusion with hash: ab527a9a6d347f364e3d185ba6d714e22d80cb3c...
# Note: switching to 'ab527a9a6d347f364e3d185ba6d714e22d80cb3c'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at ab527a9 Release 0.0.16
# Fetching updates for CodeFormer...
# Checking out commit for CodeFormer with hash: c5b4593074ba6214284d6acd5f1719b6c5d739af...
# Note: switching to 'c5b4593074ba6214284d6acd5f1719b6c5d739af'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at c5b4593 add replicate demo.
# Fetching updates for BLIP...
# Checking out commit for BLIP with hash: 48211a1594f1321b00f14c9f7a5b4813144b2fb9...
# Note: switching to '48211a1594f1321b00f14c9f7a5b4813144b2fb9'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 48211a1 Update README.md
# Installing requirements
# Installing sd-webui-infinite-image-browsing requirement: python-dotenv
# Installing sd-webui-infinite-image-browsing requirement: pyfunctional
# Launching Web UI with arguments: --no-download-sd-model --xformers --share --listen --enable-insecure-extension-access
# No SDP backend available, likely because you are running in pytorch versions < 2.0. In fact, you are using PyTorch 1.13.1+cu117. You might want to consider upgrading.
# ==============================================================================
# You are running torch 1.13.1+cu117.
# The program is tested to work with torch 2.0.0.
# To reinstall the desired version, run with commandline flag --reinstall-torch.
# Beware that this will cause a lot of large files to be downloaded, as well as
# there are reports of issues with training tab on the latest version.
#
# Use --skip-version-check commandline argument to disable this check.
# ==============================================================================
# =================================================================================
# You are running xformers 0.0.16rc425.
# The program is tested to work with xformers 0.0.20.
# To reinstall the desired version, run with commandline flag --reinstall-xformers.
#
# Use --skip-version-check commandline argument to disable this check.
# =================================================================================
# Tag Autocomplete: Could not locate model-keyword extension, Lora trigger word completion will be limited to those added through the extra networks menu.
# [AddNet] Updating model hashes...
# 0it [00:00, ?it/s]
# [AddNet] Updating model hashes...
# 0it [00:00, ?it/s]
# Checkpoint Counterfeit-V2.5_fp16.safetensors [71e703a0fc] not found; loading fallback anything-v4.0-pruned-fp16.safetensors
# Calculating sha256 for /mnt/workspace/stable-diffusion-webui/models/Stable-diffusion/anything-v4.0-pruned-fp16.safetensors: /mnt/workspace/stable-diffusion-webui/extensions/sd-webui-additional-networks/scripts/metadata_editor.py:399: GradioDeprecationWarning: The `style` method is deprecated. Please set these arguments in the constructor instead.
#   with gr.Row().style(equal_height=False):
# /mnt/workspace/stable-diffusion-webui/extensions/sd-webui-additional-networks/scripts/metadata_editor.py:521: GradioDeprecationWarning: The `style` method is deprecated. Please set these arguments in the constructor instead.
#   cover_image = gr.Image(
# Running on local URL:  http://0.0.0.0:7860
# d5f8393fea25972a9c010facc03e0a3cdec24213292105804f8078c3d88b9620
# Loading weights [d5f8393fea] from /mnt/workspace/stable-diffusion-webui/models/Stable-diffusion/anything-v4.0-pruned-fp16.safetensors
# Creating model from config: /mnt/workspace/stable-diffusion-webui/configs/v1-inference.yaml
# Loading VAE weights specified in settings: /mnt/workspace/stable-diffusion-webui/models/VAE/animevae.pt
# Applying attention optimization: xformers... done.
# Model loaded in 15.5s (calculate hash: 7.3s, load weights from disk: 0.3s, create model: 0.5s, apply weights to model: 4.3s, load VAE: 1.0s, calculate empty prompt: 1.9s).
#
# Could not create share link. Missing file: /usr/local/lib/python3.10/dist-packages/gradio/frpc_linux_amd64_v0.2.
#
# Please check your internet connection. This can happen if your antivirus software blocks the download of this file. You can install manually by following these steps:
#
# 1. Download this file: https://cdn-media.huggingface.co/frpc-gradio-0.2/frpc_linux_amd64
# 2. Rename the downloaded file to: frpc_linux_amd64_v0.2
# 3. Move the file to this location: /usr/local/lib/python3.10/dist-packages/gradio
# Startup time: 190.8s (prepare environment: 47.3s, import torch: 3.9s, import gradio: 2.1s, setup paths: 2.1s, initialize shared: 0.2s, other imports: 1.0s, setup codeformer: 0.2s, load scripts: 1.1s, create ui: 0.8s, gradio launch: 131.9s).
# Calculating sha256 for /mnt/workspace/stable-diffusion-webui/models/VAE/animevae.pt: f921fb3f29891d2a77a6571e56b8b5052420d2884129517a333c60b1b4816cdf
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#   5%|██▏                                         | 1/20 [00:00<00:04,  4.38it/s]
#  15%|██████▌                                     | 3/20 [00:00<00:02,  8.45it/s]
#  25%|███████████                                 | 5/20 [00:00<00:01,  9.93it/s]
#  35%|███████████████▍                            | 7/20 [00:00<00:01, 11.00it/s]
#  45%|███████████████████▊                        | 9/20 [00:00<00:00, 11.70it/s]
#  55%|███████████████████████▋                   | 11/20 [00:01<00:00, 12.13it/s]
#  65%|███████████████████████████▉               | 13/20 [00:01<00:00, 12.30it/s]
#  75%|████████████████████████████████▎          | 15/20 [00:01<00:00, 12.40it/s]
#  85%|████████████████████████████████████▌      | 17/20 [00:01<00:00, 12.48it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 11.55it/s]
#
# Total progress: 100%|███████████████████████████| 20/20 [00:01<00:00, 11.71it/s]
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#  10%|████▍                                       | 2/20 [00:00<00:01, 11.77it/s]
#  20%|████████▊                                   | 4/20 [00:00<00:01, 12.22it/s]
#  30%|█████████████▏                              | 6/20 [00:00<00:01, 12.40it/s]
#  40%|█████████████████▌                          | 8/20 [00:00<00:00, 12.53it/s]
#  50%|█████████████████████▌                     | 10/20 [00:00<00:00, 12.54it/s]
#  60%|█████████████████████████▊                 | 12/20 [00:00<00:00, 12.39it/s]
#  70%|██████████████████████████████             | 14/20 [00:01<00:00, 12.32it/s]
#  80%|██████████████████████████████████▍        | 16/20 [00:01<00:00, 12.25it/s]
#  90%|██████████████████████████████████████▋    | 18/20 [00:01<00:00, 12.23it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 12.31it/s]
#
# Total progress: 100%|███████████████████████████| 20/20 [00:01<00:00, 11.50it/s]
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#  10%|████▍                                       | 2/20 [00:00<00:01, 12.49it/s]
#  20%|████████▊                                   | 4/20 [00:00<00:01, 12.63it/s]
#  30%|█████████████▏                              | 6/20 [00:00<00:01, 12.55it/s]
#  40%|█████████████████▌                          | 8/20 [00:00<00:00, 12.53it/s]
#  50%|█████████████████████▌                     | 10/20 [00:00<00:00, 12.62it/s]
#  60%|█████████████████████████▊                 | 12/20 [00:00<00:00, 12.70it/s]
#  70%|██████████████████████████████             | 14/20 [00:01<00:00, 12.61it/s]
#  80%|██████████████████████████████████▍        | 16/20 [00:01<00:00, 12.66it/s]
#  90%|██████████████████████████████████████▋    | 18/20 [00:01<00:00, 12.45it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 12.57it/s]
#
# Total progress: 100%|███████████████████████████| 20/20 [00:01<00:00, 11.68it/s]
#   0%|                                                    | 0/20 [00:00<?, ?it/s]
#  10%|████▍                                       | 2/20 [00:00<00:01, 11.81it/s]
#  20%|████████▊                                   | 4/20 [00:00<00:01, 12.03it/s]
#  30%|█████████████▏                              | 6/20 [00:00<00:01, 12.34it/s]
#  40%|█████████████████▌                          | 8/20 [00:00<00:00, 12.35it/s]
#  50%|█████████████████████▌                     | 10/20 [00:00<00:00, 12.09it/s]
#  60%|█████████████████████████▊                 | 12/20 [00:00<00:00, 12.32it/s]
#  70%|██████████████████████████████             | 14/20 [00:01<00:00, 12.45it/s]
#  80%|██████████████████████████████████▍        | 16/20 [00:01<00:00, 12.56it/s]
#  90%|██████████████████████████████████████▋    | 18/20 [00:01<00:00, 12.54it/s]
# 100%|███████████████████████████████████████████| 20/20 [00:01<00:00, 12.41it/s]
#
# Total progress: 100%|███████████████████████████| 20/20 [00:01<00:00, 11.71it/s]
